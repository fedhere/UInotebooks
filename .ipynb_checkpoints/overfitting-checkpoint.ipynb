# %%
import numpy as np
import pylab as pl

import os
import json
s = json.load( open("../fbb_matplotlibrc.json") )
pl.rcParams.update(s)

import statsmodels.api as sm
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/fbianco/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/__init__.py:855: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
def myregression(x, y, method=None, formula = None):
    if formula:
            
        rm = sm.ols(formula, data={"x1" : x1, "y" : y})
    else: 
        if method == None or method == 'O':
            rm = sm.OLS(y, x)
        elif method == 'W':
            rm = sm.WLS(y, x)
        else:
            print "Problem in the way you called myregression"
            return -1
            
    reg = rm.fit()
    print "linear regression slope {}".format(reg.summary())
    return reg


def line(a, b, x):
    return a*x + b
def parabola(a, b, c, x):
    return a*x**2  + b*x + c

# %%
x = np.linspace(10,100,100)
y = parabola(0.3, 0.7, 10, x)
mrold = myregression(x, y)
mrnew = myregression(x, y)
xnew = np.linspace(10,100,10)
pl.scatter(x, y, label = "just a line")
pl.xlabel('independent variable')
pl.ylabel('dependent variable')
pl.plot(xnew, mrnew.predict(xnew), 'r', alpha=0.5)
pl.legend()
# Out:
# linear regression slope                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     1651.
# Date:                Wed, 07 Oct 2015   Prob (F-statistic):           1.48e-63
# Time:                        11:31:28   Log-Likelihood:                -727.75
# No. Observations:                 100   AIC:                             1457.
# Df Residuals:                      99   BIC:                             1460.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            23.4674      0.578     40.630      0.000        22.321    24.614
# ==============================================================================
# Omnibus:                       17.667   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.023
# Skew:                           1.148   Prob(JB):                     1.65e-05
# Kurtosis:                       3.105   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# linear regression slope                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.943
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     1651.
# Date:                Wed, 07 Oct 2015   Prob (F-statistic):           1.48e-63
# Time:                        11:31:28   Log-Likelihood:                -727.75
# No. Observations:                 100   AIC:                             1457.
# Df Residuals:                      99   BIC:                             1460.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            23.4674      0.578     40.630      0.000        22.321    24.614
# ==============================================================================
# Omnibus:                       17.667   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.023
# Skew:                           1.148   Prob(JB):                     1.65e-05
# Kurtosis:                       3.105   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mrold = mrnew
mrnew = myregression(x, y, formula = "y ~ x1 + np.sin(x1) + I((x1-5)**2)")

xnew = np.linspace(10,100,10)
pl.scatter(x, y, label = "just a line")
pl.xlabel('independent variable')
pl.ylabel('dependent variable')
pl.plot(xnew, mrnew.predict(xnew), 'r', alpha=0.5)
pl.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a8ff6fbac6d0> in <module>()
#       1 mrold = mrnew
# ----> 2 mrnew = myregression(x, y, formula = "y ~ x1 + np.sin(x1) + I((x1-5)**2)")
#       3
#       4 xnew = np.linspace(10,100,10)
#       5 pl.scatter(x, y, label = "just a line")
#
# <ipython-input-21-b56e7980c439> in myregression(x, y, method, formula)
#       2     if formula:
#       3         if method ==  None or method == 'O':
# ----> 4             rm = sm.ols(formula, data={"x1" : x1, "y" : y})
#       5         else:
#       6             print "Problem in the way you called myregression"
#
# AttributeError: 'module' object has no attribute 'ols'

# %%
y = y+np.random.rand(100)*2.5
mrold = mrnew
mrnew = myregression(x, y)

pl.scatter(x, y, label = "plus some noise")
pl.plot(xnew, mrnew.predict(xnew), 'r', alpha=0.5)
pl.plot(xnew, mrold.predict(xnew), 'k', alpha=0.5)
pl.xlabel('independent variable')
pl.ylabel('dependent variable')
pl.legend()
# Out:
# linear regression slope                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     1657.
# Date:                Wed, 07 Oct 2015   Prob (F-statistic):           1.23e-63
# Time:                        11:24:24   Log-Likelihood:                -727.62
# No. Observations:                 100   AIC:                             1457.
# Df Residuals:                      99   BIC:                             1460.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            23.4850      0.577     40.711      0.000        22.340    24.630
# ==============================================================================
# Omnibus:                       17.683   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.046
# Skew:                           1.149   Prob(JB):                     1.63e-05
# Kurtosis:                       3.106   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#y = y+np.cos(x/100*2*np.pi*10.0)
y = y+3e-3*((x-50)**2)
mrold = mrnew
mrnew = myregression(x, y, method='W')

e = np.random.rand(100)*2.5+2.5
pl.errorbar(x, y, yerr=e, label = "and some structure")
pl.plot(xnew, mrnew.predict(xnew), 'r', alpha=0.5)
pl.plot(xnew, mrold.predict(xnew), 'k', alpha=0.5)
pl.xlabel('independent variable')
pl.ylabel('dependent variable')
pl.legend()
# Out:
# linear regression slope                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.998
# Model:                            WLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 4.269e+04
# Date:                Wed, 07 Oct 2015   Prob (F-statistic):          2.72e-132
# Time:                        11:15:44   Log-Likelihood:                -221.72
# No. Observations:                 100   AIC:                             445.4
# Df Residuals:                      99   BIC:                             448.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.7571      0.004    206.627      0.000         0.750     0.764
# ==============================================================================
# Omnibus:                        9.077   Durbin-Watson:                   0.213
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.782
# Skew:                           0.763   Prob(JB):                      0.00751
# Kurtosis:                       2.859   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pl.plot([x.min(), x.max()], [0,0],  '-', color='IndianRed')
pl.plot(x, y-mrnew.predict(x), 'o', color='DarkGreen', label='residuals')
pl.plot(x, y-mrnew.predict(x), 'k-')
print mean(y-mrnew.predict(x)-(mrres[2]+mrres[1]*(x)))
print np.sqrt(sum((y-mrnew.predict(x))**2))
pl.xlabel('independent variable')
pl.ylabel('dependent variable')
pl.legend()
# Out:
# 7.39222786531
# 21.2447744739

# %%
pl.plot([x.min(), x.max()], [0,0],  '-', color='IndianRed')
pl.plot(x, y-mrnew.predict(x)-(mrres[2]+mrres[1]*(x)+mrres[0]*(x**2)), 'o', color='DarkGreen', label='residuals')
pl.plot(x, y-mrnew.predict(x)-(mrres[2]+mrres[1]*(x)+mrres[0]*(x**2)), 'k-')
print mean(y-mrnew.predict(x)-(mrres[2]+mrres[1]*(x)+mrres[0]*(x**2)))
print np.sqrt(sum((y-mrnew.predict(x)-(mrres[2]+mrres[1]*(x)+mrres[0]*(x**2)))**2))
pl.xlabel('independent variable')
pl.ylabel('dependent variable')
pl.legend()
# Out:
# -3.7568300362
# 38.2030502027

# %%
mrold = mrnew
mrnew = np.polyfit(x, y, 2)
pl.plot([x.min(), x.max()], [0,0],  '-', color='IndianRed')

e = np.random.rand(100)*2.5+2.5
#pl.errorbar(x, y, yerr=e, label = "and some structure")
pl.plot(x, y-(mrnew[2]+mrnew[1]*(x)+mrnew[0]*(x**2)), 'ro', alpha=0.5)
pl.plot(x, y-(mrnew[2]+mrnew[1]*(x)+mrnew[0]*(x**2)), 'k', alpha=0.5)
pl.xlabel('independent variable')
pl.ylabel('dependent variable')
pl.legend()
print mean(y-(mrnew[2]+mrnew[1]*(x)+mrnew[0]*(x**2)))
print np.sqrt(sum((y-(mrnew[2]+mrnew[1]*(x)+mrnew[0]*(x**2)))))
# Out:
# 3.30580007812e-14
# 1.81818593057e-06

# %% [markdown]
# #many more regression diagnostics!
# http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/regression_diagnostics.html
