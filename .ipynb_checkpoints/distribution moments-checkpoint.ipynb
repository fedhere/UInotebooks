# %%
import pylab as pl
import pandas as pd
import numpy as np
import os

# %pylab inline


import json
s = json.load( open(os.getenv('PUI2015')+"/fbb_matplotlibrc.json") )
pl.rcParams.update(s)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pl.hist(np.random.randn(1000))
# Out:
# (array([   4.,   17.,   57.,  193.,  316.,  256.,  123.,   29.,    3.,    2.]),
#  array([-3.59146996, -2.83497149, -2.07847302, -1.32197454, -0.56547607,
#          0.1910224 ,  0.94752088,  1.70401935,  2.46051783,  3.2170163 ,
#          3.97351477]),
#  <a list of 10 Patch objects>)

# %%
pl.hist(np.random.randn(1000))
pl.hist(np.random.randn(1000)+10)
# Out:
# (array([   6.,   21.,   83.,  182.,  272.,  228.,  144.,   46.,   13.,    5.]),
#  array([  6.6418315 ,   7.32723722,   8.01264294,   8.69804866,
#           9.38345438,  10.06886009,  10.75426581,  11.43967153,
#          12.12507725,  12.81048296,  13.49588868]),
#  <a list of 10 Patch objects>)

# %%
pl.hist(np.random.randn(1000)+10)
pl.hist(np.random.randn(1000)*10+10, alpha=0.5)
# Out:
# (array([   1.,    9.,   49.,  114.,  248.,  262.,  204.,   82.,   24.,    7.]),
#  array([-26.23446655, -19.31107597, -12.38768539,  -5.4642948 ,
#           1.45909578,   8.38248637,  15.30587695,  22.22926754,
#          29.15265812,  36.0760487 ,  42.99943929]),
#  <a list of 10 Patch objects>)

# %%
pl.hist(np.random.randn(1000)+10)
pl.hist(np.random.poisson(10,1000), alpha=0.5)
# Out:
# (array([   3.,   27.,  104.,  214.,  238.,  193.,  121.,   65.,   26.,    9.]),
#  array([  1. ,   2.9,   4.8,   6.7,   8.6,  10.5,  12.4,  14.3,  16.2,
#          18.1,  20. ]),
#  <a list of 10 Patch objects>)

# %%
pl.hist(np.random.randn(1000), alpha=0.5)
pl.hist(np.random.cauchy(1000))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-82e32115ae32> in <module>()
#       1 pl.hist(np.random.randn(1000), alpha=0.5)
# ----> 2 pl.hist(np.random.cauchy(1000))
#
# AttributeError: 'module' object has no attribute 'cauchy'
