# %%
# %matplotlib notebook

import numpy as np
import cv2
import matplotlib.pyplot as pl

# Create a VideoCapture object and read from input file
# to capure from camera argument would be 0
vc = cv2.VideoCapture("2017-04-01_night.mp4")

#interactive pylab is on
pl.ion()

# %%
fig = pl.figure(figsize=(10,15)).add_subplot(111)
fig.axis('off')
if vc.isOpened(): # try to get the first frame
    is_capturing, frame = vc.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
    imagecontainer = pl.imshow(frame)    
else:
    is_capturing = False

while is_capturing:
    try:    # keyboardInterrupt to stop the script
        is_capturing, frame = vc.read()
        #frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
        imagecontainer.set_data(frame)
        pl.draw()

        try:    # Avoids a NotImplementedError caused by `plt.pause`
            pl.pause(0)
        except Exception:
            pass
    except KeyboardInterrupt:
        vc.release()
# Out:
# <img src="data:image/png;base64,..." width="999.7499702051291">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f7517846dac6> in <module>()
#      12         is_capturing, frame = vc.read()
#      13         #frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
# ---> 14         imagecontainer.set_data(frame)
#      15         pl.draw()
#      16
#
# //anaconda/lib/python2.7/site-packages/matplotlib/image.pyc in set_data(self, A)
#     543         if (self._A.dtype != np.uint8 and
#     544                 not np.can_cast(self._A.dtype, np.float)):
# --> 545             raise TypeError("Image data can not convert to float")
#     546
#     547         if (self._A.ndim not in (2, 3) or
#
# TypeError: Image data can not convert to float

# %%
vc = cv2.VideoCapture("2017-04-01_night.mp4")
ax = pl.figure().add_subplot(111)
ax.axis('off')

is_capturing, frame = vc.read()
frame0 = frame.mean(2)   # makes black and white by averaging 3 colors

imagecontainer = ax.imshow(frame0, cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
i = 0

while is_capturing:
    i = i + 10
    vc.set(1, i)
    try:    # keyboardInterrupt to stop the script
        is_capturing, frame1 = vc.read()

        imagecontainer.set_data(np.abs(frame0 - frame1.mean(2)))
        pl.draw()
        try:    # Avoids a NotImplementedError caused by `plt.pause`
            pl.pause(0)
        except Exception:
            pass
    except KeyboardInterrupt:
        vc.release()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-98d4800541c0> in <module>()
#       7         is_capturing, frame1 = vc.read()
#       8
# ----> 9         imagecontainer.set_data(np.abs(frame0 - frame1.mean(2)))
#      10         pl.draw()
#      11         try:    # Avoids a NotImplementedError caused by `plt.pause`
#
# AttributeError: 'NoneType' object has no attribute 'mean'

# %%
pl.ion()
vc = cv2.VideoCapture("nyctimelapse2.mov")#manhattanTL720.mp4")

is_capturing, frame = vc.read()
frame0 = frame.mean(2)   # makes black and white by averaging 3 colors
print (frame.shape)
fig = pl.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
imagecontainer1 = ax1.imshow(frame0, cmap='gray')    
imagecontainer2 = ax2.imshow(frame0, cmap='gray')    
ax1.axis('off')
ax2.axis('off')

i = 0
while is_capturing:
    vc.set(1, i)
    i = i + 500
    try:    # keyboardInterrupt to stop the script
        is_capturing, frame1 = vc.read()
        

        imagecontainer1.set_data(cv2.cvtColor(frame1,  cv2.COLOR_BGR2RGB))
        
        imagecontainer2.set_data((frame1.mean(2) - frame0))
        pl.draw()
        frame0 = frame1.mean(2)

        try:    # Avoids a NotImplementedError caused by `plt.pause`
            pl.pause(0)
        except Exception:
            pass
    except KeyboardInterrupt:
        vc.release()
# Out:
# (712, 1168, 3)
# <img src="data:image/png;base64,..." width="1999.4999404102582">
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-099497299f84> in <module>()
#      21
#      22
# ---> 23         imagecontainer1.set_data(cv2.cvtColor(frame1,  cv2.COLOR_BGR2RGB))
#      24
#      25         imagecontainer2.set_data((frame1.mean(2) - frame0))
#
# error: /Users/travis/miniconda3/conda-bld/work/opencv-3.1.0/modules/imgproc/src/color.cpp:7341: error: (-215) scn == 3 || scn == 4 in function ipp_cvtColor

# %%
https://www.dropbox.com/home/conjointdropbox?preview=panel_no_blob_ani.mp4
