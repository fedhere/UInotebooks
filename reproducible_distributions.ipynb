# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
import numpy as np
np.random.seed(seed=123)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
firstsample=np.random.randn(100,2)
firstsample
# Out:
# array([[ -1.08563060e+00,   9.97345447e-01],
#        [  2.82978498e-01,  -1.50629471e+00],
#        [ -5.78600252e-01,   1.65143654e+00],
#        [ -2.42667924e+00,  -4.28912629e-01],
#        [  1.26593626e+00,  -8.66740402e-01],
#        [ -6.78886152e-01,  -9.47089689e-02],
#        [  1.49138963e+00,  -6.38901997e-01],
#        [ -4.43981960e-01,  -4.34351276e-01],
#        [  2.20593008e+00,   2.18678609e+00],
#        [  1.00405390e+00,   3.86186399e-01],
#        [  7.37368576e-01,   1.49073203e+00],
#        [ -9.35833868e-01,   1.17582904e+00],
#        [ -1.25388067e+00,  -6.37751502e-01],
#        [  9.07105196e-01,  -1.42868070e+00],
#        [ -1.40068720e-01,  -8.61754896e-01],
#        [ -2.55619371e-01,  -2.79858911e+00],
#        [ -1.77153310e+00,  -6.99877235e-01],
#        [  9.27462432e-01,  -1.73635683e-01],
#        [  2.84591590e-03,   6.88222711e-01],
#        [ -8.79536343e-01,   2.83627324e-01],
#        [ -8.05366518e-01,  -1.72766949e+00],
#        [ -3.90899794e-01,   5.73805862e-01],
#        [  3.38589051e-01,  -1.18304945e-02],
#        [  2.39236527e+00,   4.12912160e-01],
#        [  9.78736006e-01,   2.23814334e+00],
#        [ -1.29408532e+00,  -1.03878821e+00],
#        [  1.74371223e+00,  -7.98062735e-01],
#        [  2.96832303e-02,   1.06931597e+00],
#        [  8.90706391e-01,   1.75488618e+00],
#        [  1.49564414e+00,   1.06939267e+00],
#        [ -7.72708714e-01,   7.94862668e-01],
#        [  3.14271995e-01,  -1.32626546e+00],
#        [  1.41729905e+00,   8.07236535e-01],
#        [  4.54900806e-02,  -2.33092061e-01],
#        [ -1.19830114e+00,   1.99524074e-01],
#        [  4.68439119e-01,  -8.31154984e-01],
#        [  1.16220405e+00,  -1.09720305e+00],
#        [ -2.12310035e+00,   1.03972709e+00],
#        [ -4.03366038e-01,  -1.26029585e-01],
#        [ -8.37516723e-01,  -1.60596276e+00],
#        [  1.25523737e+00,  -6.88868984e-01],
#        [  1.66095249e+00,   8.07308186e-01],
#        [ -3.14758147e-01,  -1.08590240e+00],
#        [ -7.32461987e-01,  -1.21252313e+00],
#        [  2.08711336e+00,   1.64441230e-01],
#        [  1.15020554e+00,  -1.26735205e+00],
#        [  1.81035130e-01,   1.17786194e+00],
#        [ -3.35010762e-01,   1.03111446e+00],
#        [ -1.08456791e+00,  -1.36347154e+00],
#        [  3.79400612e-01,  -3.79176435e-01],
#        [  6.42054689e-01,  -1.97788793e+00],
#        [  7.12264635e-01,   2.59830393e+00],
#        [ -2.46259814e-02,   3.41421289e-02],
#        [  1.79549485e-01,  -1.86197571e+00],
#        [  4.26146640e-01,  -1.60540974e+00],
#        [ -4.27679598e-01,   1.24286955e+00],
#        [ -7.35216956e-01,   5.01248990e-01],
#        [  1.01273905e+00,   2.78740856e-01],
#        [ -1.37094847e+00,  -3.32475275e-01],
#        [  1.95941134e+00,  -2.02504576e+00],
#        [ -2.75786014e-01,  -5.52108071e-01],
#        [  1.20747363e-01,   7.48215617e-01],
#        [  1.60869097e+00,  -2.70232392e-01],
#        [  8.12341330e-01,   4.99740145e-01],
#        [  4.74347298e-01,  -5.63923932e-01],
#        [ -9.97321469e-01,  -1.10004311e+00],
#        [ -7.56437209e-01,   3.21686576e-01],
#        [  7.60949393e-01,   3.23468848e-01],
#        [ -5.48955096e-01,   1.80597011e+00],
#        [  1.51886562e+00,  -3.54000113e-01],
#        [ -8.23431406e-01,   1.30214954e-01],
#        [  1.26729865e+00,   3.32764977e-01],
#        [  5.56548705e-01,  -2.12080122e-01],
#        [  4.56270895e-01,   1.54454445e+00],
#        [ -2.39668781e-01,   1.43307733e-01],
#        [  2.53816477e-01,   2.83725356e-01],
#        [ -1.41188888e+00,  -1.87686866e+00],
#        [ -1.01965507e+00,   1.67942295e-01],
#        [  5.53856166e-01,  -5.30674560e-01],
#        [  1.37725748e+00,  -1.43175974e-01],
#        [  2.03159982e-02,  -1.93963871e-01],
#        [  1.34026793e-01,   7.04474074e-01],
#        [  6.65653438e-01,  -8.98422941e-01],
#        [  1.52366378e+00,  -1.09502646e+00],
#        [  7.92270141e-02,  -2.74396574e-01],
#        [ -1.04899168e+00,  -7.51205880e-02],
#        [ -7.40813773e-01,   7.29072433e-02],
#        [  4.03085961e-01,   1.47192937e+00],
#        [  3.07384219e-01,  -6.11225340e-01],
#        [ -3.91619811e-01,   1.39978106e-01],
#        [  9.34608295e-02,   1.45958927e+00],
#        [  1.39535293e+00,  -3.58935926e-01],
#        [ -5.48642128e-01,  -2.55705460e+00],
#        [ -5.48920413e-01,  -9.78057706e-01],
#        [ -3.54824458e-01,   3.91584242e-01],
#        [  1.77192329e-01,  -2.99680070e-02],
#        [  1.99582111e-01,  -1.26117773e-01],
#        [  1.97018933e-01,  -3.23105501e+00],
#        [ -2.69293490e-01,  -1.10850721e-01],
#        [ -3.41261716e-01,  -2.17946262e-01]])

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
secondsample=(3*np.random.randn(50,2)+(3.,3.))
secondsample
# Out:
# array([[  5.10993035,   1.20568401],
#        [  9.6021063 ,   5.06489079],
#        [  2.98107825,   2.38001309],
#        [  2.74043314,   0.25407879],
#        [  2.71439238,   3.83605055],
#        [  4.73862485,   4.73906934],
#        [  2.17536736,  -1.24824676],
#        [  0.99269212,   7.83657913],
#        [  5.68817494,   4.10885876],
#        [  0.71611727,   3.01093546],
#        [ -0.76700606,   1.34418937],
#        [  2.26438997,   1.9150802 ],
#        [  5.86980579,  -1.25617774],
#        [  0.40370319,  -1.12406391],
#        [ -0.71205964,   3.37216769],
#        [ -1.8013216 ,   5.26160634],
#        [  2.25955267,   3.206365  ],
#        [  3.96773021,   1.69750044],
#        [  6.09743915,   2.41697182],
#        [  4.78221077,   2.40266285],
#        [  3.87262316,   3.83898801],
#        [  3.74990982,   0.07707645],
#        [  4.30762731,   2.04312903],
#        [  4.89146409,  -3.45748033],
#        [ -1.39534867,   4.09033669],
#        [  8.58878276,   5.50517624],
#        [  0.9526472 ,  -2.07615725],
#        [  5.22805866,   2.75825033],
#        [  4.77211265,   3.34589617],
#        [  3.08892878,  11.87587634],
#        [  2.98161012,   2.52226437],
#        [  2.63565397,   1.24938985],
#        [  5.97039868,   1.938737  ],
#        [  4.90782812,   3.85380909],
#        [  6.65695759,   4.26053879],
#        [ -0.64015434,  -0.97946336],
#        [  7.22510744,   1.17386759],
#        [ -0.96180774,   0.9911442 ],
#        [  6.79387586,  -1.260639  ],
#        [  0.40051439,   0.99957747],
#        [ -0.75356962,  -0.55298202],
#        [ -1.55432393,   1.61643776],
#        [  1.9352735 ,   0.95238554],
#        [ -1.96109352,   6.76000784],
#        [ -0.98723649,   3.83410114],
#        [ -0.22429978,   5.0049506 ],
#        [  5.86749707,   0.36715924],
#        [ -2.77114719,   5.08736196],
#        [  8.62740164,   4.24708362],
#        [  3.48163326,   5.45928183]])

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
firstsampleT=firstsample.T
secondsampleT=secondsample.T

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
import pylab as pl
# %pylab inline

fig=pl.figure(figsize=(15,7))
ax=fig.add_subplot(121)
ax.scatter(firstsampleT[0], firstsampleT[1], label=r"sample 1 $\mu=(0.0,0.0),\sigma=1.0$")
ax.scatter(secondsampleT[0], secondsampleT[1], label="sample 2 $\mu=(0.1,0.1),\sigma=3.0$")
ax.set_xlabel("Gaussian random value")
ax.set_ylabel("Gaussian random value")
ax.legend()
           
ax=fig.add_subplot(122)
ax.scatter(firstsampleT[0], firstsampleT[1], color="SteelBlue", label=r"sample 1 $\mu=(0.0,0.0),\sigma=1.0$")
ax.scatter(secondsampleT[0], secondsampleT[1], color="IndianRed", label=r"sample 2 $\mu=(3.0,3.0),\sigma=3.0$")
ax.set_xlabel("Gaussian random value")
ax.set_ylabel("Gaussian random value")
ax.legend()
# Out:
# Populating the interactive namespace from numpy and matplotlib
