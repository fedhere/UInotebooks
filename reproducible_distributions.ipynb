# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys
import pylab

# %% [markdown]
# **notice the ine below**: it tells the ipython notebook that you want it to display the plots you are making in the notebook window, instead of trying and creating a pop up window for your plot. if you include the line running a cell which includes commands to plot will generate the plot int he browser (inline). If you forget this line, it will appear that your code does nothing (unless you explicityl use the pl.show() command which will then pop up the window).

# %%
# %pylab inline

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
#code here...

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean and standard deviation of the gaussian distribution
# to do that you multiply the distribution by the different sigma (one sigma, the same for each dimension), and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##NOTE: if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. one can do it by using the indeces cleverly,or  by transposing the array (switching the axes)
#
# if you want to transpose the command should look something like
#
# firstdistrib = firstdistrib.T
#
# which will replace your current variable firstdistrib, where you stored your first distribution, with the transpose of itself (i.e. switch columns and rows)

# %% [markdown]
# ##first plot them with the same color and symbol, as of they were a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is
