# %% [markdown]
# utility NB for darts gaussian distribution plot UI class 5
# FBB October 2015

# %%
import os
import pylab as pl
import numpy as np
import json
s = json.load( open("../fbb_matplotlibrc.json") )
pl.rcParams.update(s)

import pylabsetup
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/fbianco/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/__init__.py:855: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
x=np.random.rand(123)*100

a=3

y = a*x + (np.random.randn(123))*3*np.sqrt(a*x)

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 

#ax.plot(x, a*x, lw=5, color='IndianRed')
ax.plot(x, y, 'o', lw=5, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_1.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 

ax.plot(x, 0.88*a*x+0.2, lw=2, color='IndianRed')
ax.plot(x, y, 'o', lw=2, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_2bad.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 

ax.plot(x, a*x, lw=2, color='IndianRed')
ax.plot(x, y, 'o', lw=5, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_2good.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 
for i,xx in enumerate(x):
    pl.plot([xx,xx], [0.88*a*xx+0.2,y[i]], 'Orange', lw=2)
ax.plot(x, 0.88*a*x+0.2, lw=2, color='IndianRed')
ax.plot(x, y, 'o', lw=5, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_3bad.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 
for i,xx in enumerate(x):
    pl.plot([xx,xx], [a*xx,y[i]], 'w', lw=2)
ax.plot(x, a*x, lw=2, color='IndianRed')
ax.plot(x, y, 'o', lw=5, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_3good.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 
for i,xx in enumerate(x):
    pl.plot([xx,xx], [0.88*a*xx+0.2,y[i]], 'Orange', lw=2)
#ax.plot(x, a*x, lw=2, color='IndianRed')
#ax.plot(x, y, 'o', lw=5, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_4bad.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 
for i,xx in enumerate(x):
    pl.plot([xx,xx], [a*xx,y[i]], 'w', lw=2)
#ax.plot(x, a*x, lw=2, color='IndianRed')
#ax.plot(x, y, 'o', lw=5, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_4good.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
fig = pl.figure(7,figsize=(10,5))
fig.patch.set_facecolor('black')

ax = fig.add_subplot(111, axisbg='black')
ax.tick_params(color='gray', labelcolor='gray')
for spine in ax.spines.values():
        spine.set_edgecolor('gray')
ax.xaxis.grid(True, which="major", linestyle='-', color='white') 
ax.yaxis.grid(True, which="major", linestyle='-', color='white') 
for i,xx in enumerate(x):
    pl.plot([xx,xx], [np.abs(y[i]-a*xx),0], 'w', lw=2)
    pl.plot([xx,xx], [np.abs(y[i]-0.88*a*xx+0.2),0], 'Orange', lw=2)
#ax.plot(x, a*x, lw=2, color='IndianRed')
#ax.plot(x, y, 'o', lw=5, color='SteelBlue')
#ax.errorbar(x, y, yerr=np.sqrt(y), fmt='o', lw=5, color='SteelBlue')
#ax.plot([2.7,2.7],[0,0.5],color='SteelBlue',lw=3)
ax.set_xlabel("independent variable",color='gray', fontsize=22)
ax.set_ylabel("y",color='gray', fontsize=22)
#ax.plot([0,6],[0,0],color='white',lw=3)



pl.savefig(os.getenv('PUI15PLOTS')+'/resids_5good.png', facecolor=fig.get_facecolor(), edgecolor='none')

# %%
print np.sum(np.abs(y-a*xx)), np.sum(np.abs(y-0.88*a*xx+0.2))
# Out:
# 11655.3393897 12155.2165069
